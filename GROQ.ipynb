# %%
from crewai import Agent, Task, Crew, Process
import os
import pandas as pd

# %%
df = pd.read_excel('Dataset.xlsx')

# %%
df.drop(columns=['Degree', 'Batch', 'Score/800', 'Personality'], inplace=True)

# %%
df.insert(0, 'ID', df.index + 1)

# %%
def student_info(id):
    return df[df["ID"] == id].to_dict('records')[0]

# %%
student_info(100)
# Out:
# {'ID': 100,
#  'Branch': 'Mechanical Engineering',
#  'Aptitude': 49,
#  'English': 80,
#  'Quantitative': 27,
#  'Analytical': 40,
#  'Domain': 65,
#  'Computer Fundamental': 80,
#  'Coding': 100,
#  'Written English': 84,
#  'Analyst': 'Need training',
#  'Customer Service Executive': 'Need training',
#  'Graduate Engineer (Plant)': 'Need training',
#  'Graduate Engineer (R&D)': 'Need training',
#  'Network Engineer': 'Need training',
#  'Operations Executive': 'Need training',
#  'Sales Executive': 'Need training',
#  'Software Developer': 'Need training',
#  'Software Engineer': 'Need training',
#  'Software Tester': 'Need training'}

# %%
os.environ["OPENAI_API_BASE"] = 'https://api.groq.com/openai/v1'
os.environ["OPENAI_MODEL_NAME"] ='llama3-70b-8192'  # Adjust based on available model
os.environ["OPENAI_API_KEY"] ='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'

# %%
email = "hey hello you got 10 crore money jackpot lottery. Please send me your bank details to claim the prize."

# %%
data_analyst = Agent(
    role="Data Analyst",
    goal="Get the data of the student and generate meaningful insights",
    backstory="I am a data analyst and I have been working in this field for the past 5 years. I have worked on various projects and have experience in data analysis. I have a good understanding of data and can generate meaningful insights from it.",
    allow_delegation=False,
)

# %%
insights_generator = Task(
    description=f"Generate meaningful insights from the data of the student. without using numerical values just take the insights from it. if he/her got zero in any subject just do not include that subject in the insights.include the suject insights which got low marks. use this infirmation to generate insights: {student_info(100)} do not use direct data in response. do not use words like score marks etc.",
    agent= data_analyst,
    expected_output = "The insights generated from the data of the student",
)

# %%
SWOTER = Agent(
    role = "Ambious Person",
    goal = "Create a SWOT analysis for future carrer",
    backstory="""To conduct a personal SWOT analysis for future career planning, start by dividing a sheet of paper or a digital document into four quadrants labeled Strengths, Weaknesses, Opportunities, and Threats. Begin by listing your strengths, considering your natural talents, skills, achievements, and resources. Reflect on questions such as what you are naturally good at, what advantages you have over others, and what achievements set you apart from your colleagues. Next, identify your weaknesses by acknowledging areas where you need improvement, bad habits, and skills that require development. Ask yourself about your negative traits, areas where your education or training may be lacking, and situations where you lack confidence. Then, explore opportunities for growth within your industry, company, and desired career path by considering the state of your industry, emerging technologies, and the potential support from your professional network. Finally, address potential threats to your career goals, such as external factors like industry changes, economic conditions, and competition, as well as internal challenges like bad habits and skill deficiencies. Use this SWOT analysis to identify goals, devise strategies, and create action plans for advancing your career, ensuring an honest and balanced assessment to stay motivated and effective. An example of a personal SWOT analysis might include strengths like being a creative thinker, working well under pressure, having an advanced degree, being organized and personable, being resourceful, and asking good questions. Weaknesses might include procrastination, tardiness, past issues with coworkers, less experience with AI technology, shyness in meetings, and presentation anxiety. Opportunities might involve proposing new market strategies, utilizing AI tools, seeking advice from mentors, taking online courses, and working with a career coach. Threats could include the need for more education, slower project completion compared to peers, being viewed as unreliable due to bad habits, potential job obsolescence due to AI advancements, and increasing competition from new talent. Use this SWOT analysis to brainstorm goals and strategize action plans for career advancement, ensuring an honest and balanced approach to create an effective and motivating assessment.""",
    allow_delegation = False,
)

# %%
FORMATTER = Agent(
    role = "chatbot response formatter",
    goal = "you have to carefully format the response to the four quadrants of SWOT analysis",
    backstory="You are very good at formatting the text data and you have to format the response to the four quadrants of SWOT analysis. try make response more like human.",
    allow_delegation = False,
)

# %%
SWOT_analysis = Task(
    description = f"""Create a SWOT analysis for a student using the provided detailed information. Focus on uncovering valuable insights that highlight the student's strengths and areas for growth beyond academic scores. For example, instead of focusing on specific scores, consider their skills, interests, and experiences that contribute positively to their academic journey. Identify strengths that set them apart, areas where improvement could enhance their abilities, opportunities for future development based on their interests, and potential challenges they may encounter. Ensure the analysis is constructive and balanced, emphasizing their potential and positive attributes. Use supportive and motivating language to inspire confidence in the student about their capabilities and future opportunities""",
    agent = SWOTER,
    expected_output = "Perfect SWOT analysis for the student.",
)

# %%
formating = Task(
    description = """take the SWOT analysis and format it for human readable format.remove unnecessary special characters like *. use '-' for bullet points.remove the mini title from in front of every point.""",
    agent = FORMATTER,
    expected_output = "Perfectly formatted SWOT analysis"
)

# %%
crew = Crew(
    agents=[data_analyst,SWOTER, FORMATTER],
    tasks=[insights_generator,SWOT_analysis, formating],
    verbose=2,
    process=Process.sequential
)
# Out:
# 2024-07-03 17:27:14,421 - 22368 - __init__.py-__init__:518 - WARNING: Overriding of current TracerProvider is not allowed

# %%
output = crew.kickoff()
# Out:
#  [2024-07-03 17:27:16][DEBUG]: == Working Agent: Data Analyst
#  [2024-07-03 17:27:16][INFO]: == Starting Task: Generate meaningful insights from the data of the student. without using numerical values just take the insights from it. if he/her got zero in any subject just do not include that subject in the insights.include the suject insights which got low marks. use this infirmation to generate insights: {'ID': 100, 'Branch': 'Mechanical Engineering', 'Aptitude': 49, 'English': 80, 'Quantitative': 27, 'Analytical': 40, 'Domain': 65, 'Computer Fundamental': 80, 'Coding': 100, 'Written English': 84, 'Analyst': 'Need training', 'Customer Service Executive': 'Need training', 'Graduate Engineer (Plant)': 'Need training', 'Graduate Engineer (R&D)': 'Need training', 'Network Engineer': 'Need training', 'Operations Executive': 'Need training', 'Sales Executive': 'Need training', 'Software Developer': 'Need training', 'Software Engineer': 'Need training', 'Software Tester': 'Need training'} do not use direct data in response. do not use words like score marks etc.
#  [2024-07-03 17:27:18][DEBUG]: == [Data Analyst] Task output: The insights generated from the data of the student indicate that the individual excels in areas that require technical skills, particularly in coding and computer fundamentals. They also possess strong written and verbal communication skills, as evident from their performance in Written English.
#
# The student's aptitude and analytical abilities are areas that require improvement, suggesting that they may need to focus on developing their problem-solving skills and logical reasoning. Additionally, their performance in Domain Knowledge is average, implying that they may need to work on strengthening their understanding of their chosen field, Mechanical Engineering.
#
# It is also observed that the student requires training in various roles, including Analyst, Customer Service Executive, Graduate Engineer, Network Engineer, Operations Executive, Sales Executive, Software Developer, Software Engineer, and Software Tester.
#
#
#  [2024-07-03 17:27:18][DEBUG]: == Working Agent: Ambious Person
#  [2024-07-03 17:27:18][INFO]: == Starting Task: Create a SWOT analysis for a student using the provided detailed information {'ID': 10, 'Branch': 'Electronics & TeleCommunication Engineering', 'Aptitude': 64, 'English': 73, 'Quantitative': 67, 'Analytical': 53, 'Domain': 0, 'Computer Fundamental': 67, 'Coding': 94, 'Written English': 88, 'Analyst': 'Need practice', 'Customer Service Executive': 'Good to go', 'Graduate Engineer (Plant)': 'Need training', 'Graduate Engineer (R&D)': 'Need training', 'Network Engineer': 'Good to go', 'Operations Executive': 'Need practice', 'Sales Executive': 'Good to go', 'Software Developer': 'Need practice', 'Software Engineer': 'Good to go', 'Software Tester': 'Good to go'}. Focus on uncovering valuable insights that highlight the student's strengths and areas for growth beyond academic scores. For example, instead of focusing on specific scores, consider their skills, interests, and experiences that contribute positively to their academic journey. Identify strengths that set them apart, areas where improvement could enhance their abilities, opportunities for future development based on their interests, and potential challenges they may encounter. Ensure the analysis is constructive and balanced, emphasizing their potential and positive attributes. Use supportive and motivating language to inspire confidence in the student about their capabilities and future opportunities
#  [2024-07-03 17:27:21][DEBUG]: == [Ambious Person] Task output: **Personal SWOT Analysis for the Student**
#
# **Strengths:**
#
# * Technical skills: Excel in coding and computer fundamentals, indicating a strong foundation in technical aspects of Electronics & TeleCommunication Engineering.
# * Communication skills: Possess strong written and verbal communication skills, as evident from the high score in Written English.
# * Problem-solving potential: With practice and training, the student can develop their analytical and problem-solving skills, which will enhance their overall abilities.
# * Versatility: The student has the potential to excel in various roles, including Network Engineer, Software Engineer, Software Tester, and Sales Executive, where they are considered "Good to go".
#
# **Weaknesses:**
#
# * Aptitude: The student's aptitude score is 64, indicating a need for improvement in this area.
# * Analytical skills: The score of 53 in Analytical skills suggests that the student needs to focus on developing their logical reasoning and problem-solving abilities.
# * Domain Knowledge: The student's performance in Domain Knowledge is average, implying a need to strengthen their understanding of Electronics & TeleCommunication Engineering.
# * Training requirements: The student requires training in various roles, including Analyst, Customer Service Executive, Graduate Engineer, Operations Executive, and Software Developer.
#
# **Opportunities:**
#
# * Role exploration: The student has the opportunity to explore various roles, including Network Engineer, Software Engineer, Software Tester, and Sales Executive, where they have a strong foundation.
# * Skill development: Focusing on improving aptitude, analytical skills, and Domain Knowledge will enhance the student's overall abilities and increase their chances of success.
# * Mentorship: Seeking guidance from experienced professionals in the field can help the student gain valuable insights and develop their skills further.
# * Online courses: Taking online courses or attending workshops can help the student improve their skills and knowledge in specific areas.
#
# **Threats:**
#
# * Competition: The student may face competition from peers who have stronger aptitude, analytical skills, and Domain Knowledge.
# * Skill obsolescence: The rapid advancement of technology can make certain skills obsolete, and the student may need to continuously update their skills to remain relevant.
# * Lack of training: Failure to receive adequate training in desired roles can hinder the student's career progress.
# * Self-doubt: The student's confidence may be affected by their weaknesses, leading to self-doubt and decreased motivation.
#
# This SWOT analysis aims to provide a balanced and constructive assessment of the student's strengths, weaknesses, opportunities, and threats. By acknowledging their strengths and weaknesses, the student can focus on developing their skills and knowledge, ultimately leading to a successful career in Electronics & TeleCommunication Engineering.
#
#
#  [2024-07-03 17:27:21][DEBUG]: == Working Agent: chatbot response formatter
#  [2024-07-03 17:27:21][INFO]: == Starting Task: take the SWOT analysis and format it for human readable format.remove unnecessary special characters like *. use '-' for bullet points.remove the mini title from in front of every point.
#  [2024-07-03 17:27:26][DEBUG]: == [chatbot response formatter] Task output: Personal SWOT Analysis for the Student
#
# Strengths:
# - Technical skills: Excel in coding and computer fundamentals, indicating a strong foundation in technical aspects of Electronics & TeleCommunication Engineering.
# - Communication skills: Possess strong written and verbal communication skills, as evident from the high score in Written English.
# - Problem-solving potential: With practice and training, the student can develop their analytical and problem-solving skills, which will enhance their overall abilities.
# - Versatility: The student has the potential to excel in various roles, including Network Engineer, Software Engineer, Software Tester, and Sales Executive, where they are considered "Good to go".
#
# Weaknesses:
# - Aptitude: The student's aptitude score is 64, indicating a need for improvement in this area.
# - Analytical skills: The score of 53 in Analytical skills suggests that the student needs to focus on developing their logical reasoning and problem-solving abilities.
# - Domain Knowledge: The student's performance in Domain Knowledge is average, implying a need to strengthen their understanding of Electronics & TeleCommunication Engineering.
# - Training requirements: The student requires training in various roles, including Analyst, Customer Service Executive, Graduate Engineer, Operations Executive, and Software Developer.
#
# Opportunities:
# - Role exploration: The student has the opportunity to explore various roles, including Network Engineer, Software Engineer, Software Tester, and Sales Executive, where they have a strong foundation.
# - Skill development: Focusing on improving aptitude, analytical skills, and Domain Knowledge will enhance the student's overall abilities and increase their chances of success.
# - Mentorship: Seeking guidance from experienced professionals in the field can help the student gain valuable insights and develop their skills further.
# - Online courses: Taking online courses or attending workshops can help the student improve their skills and knowledge in specific areas.
#
# Threats:
# - Competition: The student may face competition from peers who have stronger aptitude, analytical skills, and Domain Knowledge.
# - Skill obsolescence: The rapid advancement of technology can make certain skills obsolete, and the student may need to continuously update their skills to remain relevant.
# - Lack of training: Failure to receive adequate training in desired roles can hinder the student's career progress.
# - Self-doubt: The student's confidence may be affected by their weaknesses, leading to self-doubt and decreased motivation.
#
# This SWOT analysis aims to provide a balanced and constructive assessment of the student's strengths, weaknesses, opportunities, and threats. By acknowledging their strengths and weaknesses, the student can focus on developing their skills and knowledge, ultimately leading to a successful career in Electronics & TeleCommunication Engineering.
