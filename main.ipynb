# %%
import pandas as pd

# %%
df = pd.read_excel('Dataset.xlsx')

# %%
column_names = ['Branch', 'Degree', 'Batch', 'Score/800', 
                'Aptitude', 'English', 'Quantitative', 'Analytical', 'Domain', 'Computer Fundamental', 'Coding', 'Written English', 'Personality', 
                'Analyst', 'Customer Service Executive', 'Graduate Engineer (Plant)', 'Graduate Engineer (R&D)', 'Network Engineer', 'Operations Executive', 'Sales Executive', 'Software Developer', 'Software Engineer', 'Software Tester']

# %%
df
# Out:
#                                           Branch    Degree  Batch  Score/800  \
# 0                           Computer Engineering  B. Tech.   2024        653
# 1                         Information Technology  B. Tech.   2024        650
# 2                         Information Technology  B. Tech.   2024        646
# 3                           Computer Engineering  B. Tech.   2024        626
# 4    Electronics & TeleCommunication Engineering  B. Tech.   2024        623
# ..                                           ...       ...    ...        ...
# 304                       Mechanical Engineering        BE   2024        261
# 305                         Computer Engineering  B. Tech.   2024        250
# 306  Electronics & TeleCommunication Engineering  B. Tech.   2024        242
# 307                       Information Technology  B. Tech.   2024        236
# 308                       Mechanical Engineering        BE   2024        206
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Branch                      309 non-null    object
#  1   Degree                      309 non-null    object
#  2   Batch                       309 non-null    int64
#  3   Score/800                   309 non-null    int64
#  4   Aptitude                    309 non-null    int64
#  5   English                     309 non-null    int64
#  6   Quantitative                309 non-null    int64
#  7   Analytical                  309 non-null    int64
#  8   Domain                      309 non-null    int64
#  9   Computer Fundamental        309 non-null    int64
#  10  Coding                      309 non-null    int64
#  11  Written English             309 non-null    int64
#  12  Personality                 309 non-null    object
# ...

# %%
df['Software Developer'].unique()
# Out:
# array(['Good to go', 'Need practice', 'Need training'], dtype=object)

# %%
df['Personality'].unique()
# Out:
# array(['UCEsT', 'OCEAT', 'oCEAT', 'UDeaN', 'UDEST', 'odeAT', 'UdEaT',
#        'uCEAt', 'UceSN', 'UdESt', 'OcEaT', 'OCEaT', 'UCEAT', 'UCESt',
#        'OCeAT', 'OcEST', 'odEST', 'UCESN', 'ucest', 'UdEST', 'UdEAT',
#        'oCEaT', 'oCEST', 'ocEaT', 'OCEsT', 'odEAT', 'odEAt', 'uCEAT',
#        'ODEST', 'UdEsn', 'UdIST', 'UcesN', 'UceSt', 'ucEST', 'UDiSN',
#        'UCEST', 'uCEST', 'OCEST', 'uCEaT', 'UDeAt', 'udesT', 'oceaT',
#        'UcEsT', 'OdEST', 'odeSt', 'uCest', 'UdISn', 'UCEsn', 'UdiSN',
#        'UdESn', 'ocEST', 'oCeAt', 'ocEsT', 'UDISn', 'UceST', 'UDISN',
#        'ocEAT', 'UCEst', 'oCIAt', 'uDiSt', 'udESt', 'UDeSN', 'UDESN',
#        'oCEsT', 'UcESt', 'UcEAT', 'ucEAT', 'oDESn', 'UDiSt', 'UdISt',
#        'UDeSt', 'OciSt', 'UcEst', 'odiST', 'udEST', 'UDESt', 'UcEST',
#        'UCeAt', 'UcESn', 'UdeST', 'UDeSn', 'UdeSn', 'UdeSt', 'UcEaT',
#        'odEsT', 'UcEAt', 'UDIsN', 'UDESn', 'UcESN', 'OcEAT', 'UDEAT',
# ...

# %%
df['Degree'].unique(), df['Branch'].unique(), df['Batch'].unique()
# Out:
# (array(['B. Tech.', 'BE'], dtype=object),
#  array(['Computer Engineering', 'Information Technology',
#         'Electronics & TeleCommunication Engineering',
#         'Artificial Intelligence and Data Science',
#         'Mechanical Engineering', 'Civil Engineering'], dtype=object),
#  array([2024], dtype=int64))

# %%
df.iloc[:,3:12].describe()
# Out:
#         Score/800    Aptitude     English  Quantitative  Analytical  \
# count  309.000000  309.000000  309.000000    309.000000  309.000000
# mean   454.653722   43.770227   50.132686     37.067961   44.148867
# std     93.471781   15.491377   20.772544     19.551096   19.129697
# min    206.000000    0.000000    0.000000      0.000000    0.000000
# 25%    392.000000   33.000000   33.000000     27.000000   33.000000
# 50%    467.000000   42.000000   47.000000     33.000000   47.000000
# 75%    529.000000   56.000000   67.000000     47.000000   60.000000
# max    653.000000   89.000000   93.000000     93.000000   93.000000
#
#            Domain  Computer Fundamental      Coding  Written English
# count  309.000000            309.000000  309.000000       309.000000
# mean    23.592233             44.605178   16.177994        43.605178
# std     24.939057             24.974522   28.915417        26.760350
# min      0.000000              0.000000    0.000000         0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Branch                      309 non-null    object
#  1   Degree                      309 non-null    object
#  2   Batch                       309 non-null    int64
#  3   Score/800                   309 non-null    int64
#  4   Aptitude                    309 non-null    int64
#  5   English                     309 non-null    int64
#  6   Quantitative                309 non-null    int64
#  7   Analytical                  309 non-null    int64
#  8   Domain                      309 non-null    int64
#  9   Computer Fundamental        309 non-null    int64
#  10  Coding                      309 non-null    int64
#  11  Written English             309 non-null    int64
#  12  Personality                 309 non-null    object
# ...
